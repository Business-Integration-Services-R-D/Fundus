# %% [markdown]
# aşağıdaki hücreyi çalıştırıp ortamı kuralım:

# %%
# !pip install -q gradio torch torchvision timm gdown
# !gdown 1e8-SUKbNqAYfZHpO4Y5ZgZNyiQGCjfHW
# !unzip -qq "/content/fundus-app.zip" -d /content/fundus
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1e8-SUKbNqAYfZHpO4Y5ZgZNyiQGCjfHW
# From (redirected): https://drive.google.com/uc?id=1e8-SUKbNqAYfZHpO4Y5ZgZNyiQGCjfHW&confirm=t&uuid=3d6a3fa1-3a22-4493-a13c-6c8bc7a4eb95
# To: /content/fundus-app.zip
# 100% 2.13G/2.13G [00:25<00:00, 84.2MB/s]

# %% [markdown]
# aşağıdaki hücreyi çalıştırıp **.gradio.live** ile biten linke tıklayıp uygulamayı kolayca kullanabilirsiniz.

# %%
# %cd /content/fundus
# !python app.py
# Out:
# /content/fundus
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://18fdfab91ebd277db2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
